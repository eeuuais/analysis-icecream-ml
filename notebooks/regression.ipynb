# %%
import pandas as pd

# CSV 파일 불러오기
icecream_sales = pd.read_csv('C:/Users/09048/2025project/analysis-icecream-ml/data/expanded_icecream.csv')

# 데이터 확인
icecream_sales.head()
# Out:
#    번호        영업일자              카드번호      승인번호  승인금액        승인일자  \
# 0   1  2021-02-15  944012**********  70881175  4800  2021-02-15
# 1   2  2021-02-15  944012**********  70881175  4800  2021-02-15
# 2   3  2021-02-15  944012**********  70881175  4800  2021-02-15
# 3   4  2021-02-15  944012**********  70881175  4800  2021-02-15
# 4   5  2021-02-15  944012**********  70881175  4800  2021-02-15
#
#                   승인시간    매입사  영수번호      메뉴코드      메뉴명  판매가격      요일        월  \
# 0  1900-01-01 11:04:42  비씨카드사     2  B0000867     빼빼로바   600  Monday  2021-02
# 1  1900-01-01 11:04:42  비씨카드사     2  B0000463    초코쿠키바   400  Monday  2021-02
# 2  1900-01-01 11:04:42  비씨카드사     2  B0000705  가나 아이스바   600  Monday  2021-02
# 3  1900-01-01 11:04:42  비씨카드사     2  B0000705  가나 아이스바   600  Monday  2021-02
# 4  1900-01-01 11:04:42  비씨카드사     2  B0000531    체리마루바   400  Monday  2021-02
#
#    시간대
# 0   11
# 1   11
# 2   11
# 3   11
# 4   11

# %% [markdown]
# - 승인일자와 영업일자가 있지만 일단은 승인일자로 테스트해보고자 한다.

# %%
icecream_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60995 entries, 2021-02-15 to 2022-07-06
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      60995 non-null  int64
#  1   영업일자    60995 non-null  object
#  2   카드번호    60995 non-null  object
#  3   승인번호    60995 non-null  int64
#  4   승인금액    60995 non-null  int64
#  5   승인시간    60995 non-null  object
#  6   매입사     60995 non-null  object
#  7   영수번호    60995 non-null  int64
#  8   메뉴코드    60995 non-null  object
#  9   메뉴명     60995 non-null  object
#  10  판매가격    60995 non-null  int64
#  11  요일      60995 non-null  object
#  12  월       60995 non-null  object
#  13  시간대     60995 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 7.0+ MB

# %%
# 날짜 컬럼은 인덱스로 설정해야 시계열 데이터로 다룰 수 있다.
icecream_sales['승인일자'] = pd.to_datetime(icecream_sales['승인일자'])
icecream_sales.set_index('승인일자', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\09048\anaconda3\envs\analysis-icecream-ml\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '승인일자'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 날짜 컬럼은 인덱스로 설정해야 시계열 데이터로 다룰 수 있다.
# ----> 2 icecream_sales['승인일자'] = pd.to_datetime(icecream_sales['승인일자'])
#       3 icecream_sales.set_index('승인일자', inplace=True)
#
# File c:\Users\09048\anaconda3\envs\analysis-icecream-ml\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\09048\anaconda3\envs\analysis-icecream-ml\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: '승인일자'

# %%
icecream_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60995 entries, 2021-02-15 to 2022-07-06
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      60995 non-null  int64
#  1   영업일자    60995 non-null  object
#  2   카드번호    60995 non-null  object
#  3   승인번호    60995 non-null  int64
#  4   승인금액    60995 non-null  int64
#  5   승인시간    60995 non-null  object
#  6   매입사     60995 non-null  object
#  7   영수번호    60995 non-null  int64
#  8   메뉴코드    60995 non-null  object
#  9   메뉴명     60995 non-null  object
#  10  판매가격    60995 non-null  int64
#  11  요일      60995 non-null  object
#  12  월       60995 non-null  object
#  13  시간대     60995 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 7.0+ MB
